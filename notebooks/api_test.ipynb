# %%
from datagovindia import DataGovIndia

my_api = "579b464db66ec23bdd00000146133a598f2e47f549e75439ab928921"
dgi = DataGovIndia()
# dgi.sync_metadata()

# %%
df = dgi.search('agriculture')

# %%
# Search for word 'Mandi' in dataframe
agri_rid = '35985678-0d79-46b4-9ed6-6f13308a1d24'
example_rid = '48f328d5-5dab-4221-88ed-deec1698d611'

dgi.get_resource_info(agri_rid)
# Out:
# 2025-10-25 22:11:37,705 - ERROR - Failed to fetch data: RetryError[<Future at 0x11119f0b0 state=finished raised HTTPError>]
# {}
